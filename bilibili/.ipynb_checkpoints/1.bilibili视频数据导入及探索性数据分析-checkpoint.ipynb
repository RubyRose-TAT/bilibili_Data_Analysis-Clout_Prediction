# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use({'figure.figsize':(15,10)})

plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
df = pd.read_csv('data/bilibili_week_popular.CSV')

# %%
df
# Out:
#               作者       粉丝                                                 标题  \
# 0           木鱼水心  7965289                            许三多孤身入敌！老A全军覆没？《士兵突击》P8
# 1        歪果仁研究协会  4049110                                    我在第一次见面的地方向她求婚了
# 2          是老胡没错   813083                                          社 交 废 物 4
# 3            鲁大能  1964943                            “你 开 炮 啊 ！”【迫击炮快乐阴人流#2】
# 4         进击的金厂长  2689136                              当 代 毕 业 生 生 存 现 状 3.0
# ...          ...      ...                                                ...
# 1896        九点视频      993                        脚动刹车？男子坐车感觉有东西在撞脚，随手扒开地垫惊呆了
# 1897       秃了呃呃呃     4881  在一起快6年  从大学校园到出社会工作2年  结婚前被出轨  半条命没了  太痛苦太窒息了 ...
# 1898  阳新县融媒体云上阳新     1044                      萌娃开着自己的小拖拉机，帮父母收菜手脚麻利，装满就开车回去
# 1899     投掷狂魔Dav   117573                                           我的那些失败合集
# 1900       熊熊卷球球    15614                                        《伸腿瞪眼丸plus》
#
# ...

# %%
df.head()
# Out:
#         作者       粉丝                       标题      点赞      硬币     收藏     分享  \
# 0     木鱼水心  7965289  许三多孤身入敌！老A全军覆没？《士兵突击》P8  247781  143746  24366   2807
# 1  歪果仁研究协会  4049110          我在第一次见面的地方向她求婚了  207752  228697  28627   5070
# 2    是老胡没错   813083                社 交 废 物 4  203563   62321  32952  17195
# 3      鲁大能  1964943  “你 开 炮 啊 ！”【迫击炮快乐阴人流#2】  167715  122199  29608   5901
# 4   进击的金厂长  2689136    当 代 毕 业 生 生 存 现 状 3.0  128799  116933  38051   6813
#
#       弹幕       播放    评论              上传时间              爬取时间       标签   分区  \
# 0  28080  1618512  7246  2021/11/22 22:41  2021/11/25 18:00  影视 影视杂谈  all
# 1  16583  1188497  8594  2021/11/23 20:20  2021/11/25 18:00    生活 日常  all
# 2   7308  2302605  6795  2021/11/22 17:35  2021/11/25 18:00    生活 搞笑  all
# 3   9272  1195430  1883  2021/11/23 12:00  2021/11/25 18:01  游戏 网络游戏  all
# 4   4448  1600703  3357  2021/11/22 19:42  2021/11/25 18:01    动画 综合  all
#
#           时间
# 0  67.316667
# 1  45.666667
# 2  72.416667
# ...

# %%
df.shape
# Out:
# (1901, 15)

# %%
df.dtypes
# Out:
# 作者       object
# 粉丝        int64
# 标题       object
# 点赞        int64
# 硬币        int64
# 收藏        int64
# 分享        int64
# 弹幕        int64
# 播放        int64
# 评论        int64
# 上传时间     object
# 爬取时间     object
# 标签       object
# 分区       object
# 时间      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1901 entries, 0 to 1900
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   作者      1901 non-null   object
#  1   粉丝      1901 non-null   int64
#  2   标题      1901 non-null   object
#  3   点赞      1901 non-null   int64
#  4   硬币      1901 non-null   int64
#  5   收藏      1901 non-null   int64
#  6   分享      1901 non-null   int64
#  7   弹幕      1901 non-null   int64
#  8   播放      1901 non-null   int64
#  9   评论      1901 non-null   int64
#  10  上传时间    1892 non-null   object
#  11  爬取时间    1901 non-null   object
#  12  标签      1891 non-null   object
#  13  分区      1901 non-null   object
#  14  时间      1901 non-null   float64
# dtypes: float64(1), int64(8), object(6)
# memory usage: 222.9+ KB

# %% [markdown]
# ## 统计特征

# %%
df.describe()
# Out:
#                  粉丝            点赞            硬币            收藏            分享  \
# count  1.901000e+03  1.901000e+03  1.901000e+03  1.901000e+03  1.901000e+03
# mean   6.751044e+05  6.412466e+04  2.377727e+04  1.871235e+04  6.454529e+03
# std    1.522766e+06  1.931961e+05  1.540955e+05  1.146398e+05  5.164087e+04
# min    0.000000e+00  1.490000e+02  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.167800e+04  8.365000e+03  5.540000e+02  1.317000e+03  2.340000e+02
# 50%    1.554880e+05  2.271400e+04  2.587000e+03  3.583000e+03  8.020000e+02
# 75%    6.332950e+05  6.100900e+04  1.189300e+04  1.082100e+04  3.186000e+03
# max    1.964193e+07  4.482180e+06  4.626396e+06  3.113580e+06  1.874838e+06
#
#                  弹幕            播放             评论            时间
# count  1.901000e+03  1.901000e+03    1901.000000  1.901000e+03
# mean   3.590780e+03  9.109694e+05    1799.129406  5.252268e+03
# std    3.144019e+04  3.862687e+06    7028.945199  7.336792e+04
# ...

# %% [markdown]
# 返回该数据类型的相关系数矩阵

# %%
df.corr()
# Out:
#           粉丝        点赞        硬币        收藏        分享        弹幕        播放  \
# 粉丝  1.000000  0.131253  0.128341  0.039574  0.034746  0.082195  0.042971
# 点赞  0.131253  1.000000  0.897603  0.904791  0.842462  0.592915  0.902964
# 硬币  0.128341  0.897603  1.000000  0.880471  0.710232  0.514800  0.757111
# 收藏  0.039574  0.904791  0.880471  1.000000  0.871855  0.710456  0.917095
# 分享  0.034746  0.842462  0.710232  0.871855  1.000000  0.724025  0.935586
# 弹幕  0.082195  0.592915  0.514800  0.710456  0.724025  1.000000  0.761815
# 播放  0.042971  0.902964  0.757111  0.917095  0.935586  0.761815  1.000000
# 评论  0.100667  0.768964  0.588712  0.756705  0.913891  0.662586  0.873495
# 时间 -0.009045 -0.005307  0.002767  0.000982  0.001942  0.021895  0.018635
#
#           评论        时间
# 粉丝  0.100667 -0.009045
# 点赞  0.768964 -0.005307
# 硬币  0.588712  0.002767
# 收藏  0.756705  0.000982
# 分享  0.913891  0.001942
# 弹幕  0.662586  0.021895
# 播放  0.873495  0.018635
# 评论  1.000000  0.005262
# ...

# %% [markdown]
# ## 可视化

# %%
up = df['up主'].value_counts()[:50]
up

# %%
data_pairs = [list(z) for z in zip(up.index.tolist(), up.values.tolist())]
pie3 = (Pie(
    init_opts=opts.InitOpts(theme='dark', width='1000px', height='800px')).add(
        "", data_pairs, radius=["40%", "65%"]).set_global_opts(
            title_opts=opts.TitleOpts(
                title="上热门作品数量\n\nUP主Top50",
                pos_left='center',
                pos_top='center',
                title_textstyle_opts=opts.TextStyleOpts(color='#FF6A6A',
                                                        font_size=30,
                                                        font_weight='bold'),
            ),
            visualmap_opts=opts.VisualMapOpts(is_show=False,
                                              min_=8,
                                              max_=64,
                                              is_piecewise=False,
                                              dimension=0,
                                              range_color=[
                                                  '#9400D3', '#008afb',
                                                  '#ffec4a', '#FFA500',
                                                  '#ce5777'
                                              ]),
            legend_opts=opts.LegendOpts(is_show=False, pos_top='5%'),
        ).set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}",
                                                    font_size=12),
                          tooltip_opts=opts.TooltipOpts(trigger="item",
                                                        formatter="{b}: {c}"),
                          itemstyle_opts={
                              "normal": {
                                  "barBorderRadius": [30, 30, 30, 30],
                                  'shadowBlur': 10,
                                  'shadowColor': 'rgba(0,191,255,0.5)',
                                  'shadowOffsetY': 1,
                                  'opacity': 0.8
                              }
                          }))
st_pyecharts(pie3)

# %%
df.hist(bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'粉丝'}>,
#         <AxesSubplot:title={'center':'点赞'}>,
#         <AxesSubplot:title={'center':'硬币'}>],
#        [<AxesSubplot:title={'center':'收藏'}>,
#         <AxesSubplot:title={'center':'分享'}>,
#         <AxesSubplot:title={'center':'弹幕'}>],
#        [<AxesSubplot:title={'center':'播放'}>,
#         <AxesSubplot:title={'center':'评论'}>,
#         <AxesSubplot:title={'center':'时间'}>]], dtype=object)

# %%
sns.pairplot(df)

# %%
df1= df.drop(['播放'],axis=1)
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots=True,figsize=(20,45))
plt.show()

# %%
df.plot(kind='hist',bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(data=df[['点赞','收藏','硬币']])
plt.title('一些特征的箱型图')
# Out:
# Text(0.5, 1.0, '一些特征的箱型图')

# %%
sns.violinplot(data=df[['点赞','收藏','硬币']])
plt.title('一些特征的小提琴图')
# Out:
# Text(0.5, 1.0, '一些特征的小提琴图')

# %%
sns.distplot(df['点赞'])
sns.distplot(df['收藏'])
sns.distplot(df['硬币'])
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
from scipy import stats
res = stats.probplot(df['播放'],plot=plt)

# %%
sns.heatmap(df.corr(),square=True,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
plt.style.use({'figure.figsize':(10,8)})
for each in df.columns:
    plt.scatter(df[each], df['播放'])
    plt.title('{}与播放量散点图'.format(each))
    plt.xlabel(each)
    plt.ylabel('播放量')
    plt.yticks (range(0,60,5))
    plt.grid()
    plt.show ()
# Out:
# E:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12442 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# E:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 12442 missing from current font.
#   font.set_text(s, 0, flags=flags)
# E:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 165 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# E:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12441 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# E:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# E:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 334 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# ## 特征选择

# %%
df.head()

# %%
x=df.drop(['播放'],axis=1)
y=df['播放']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn. feature_selection import f_regression
SelectKBest = SelectKBest(f_regression,k=3)
bestFeature = SelectKBest.fit_transform(x,y)
SelectKBest.get_support()
x.columns[SelectKBest.get_support()]

# %%
sns.pairplot(df[['收藏', '硬币', '点赞','播放']])

# %%
df.corr()
